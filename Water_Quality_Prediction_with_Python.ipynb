# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Task
#
# Using the above dataset, Municipal Corporation in a particular city wants to construct a classification model that can label any new water sample as either safe or unsafe for drinking.
# Construct such a model in Python by trying two classification algorithms - random forest and support vector classification.

# %%
# Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.simplefilter('ignore')

# %%
# Reading Data
data = pd.read_csv('QualityPrediction.csv')

# %%
# Check first 5 rows
data.head()
# Out:
#    aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65     9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32    21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01    14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36    11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92    24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# 3      1.08      0.71  ...  0.016      1.41      1.29    0.004         9.12
# 4      0.61      0.13  ...  0.117      6.74      1.11    0.003        16.90
#
# ...

# %%
# Checking rows and columns of dataset
data.shape
# Out:
# (7996, 21)

# %%
# Getting some basic information about dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7996 entries, 0 to 7995
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7996 non-null   float64
#  1   ammonia      7996 non-null   float64
#  2   arsenic      7996 non-null   float64
#  3   barium       7996 non-null   float64
#  4   cadmium      7996 non-null   float64
#  5   chloramine   7996 non-null   float64
#  6   chromium     7996 non-null   float64
#  7   copper       7996 non-null   float64
#  8   flouride     7996 non-null   float64
#  9   bacteria     7996 non-null   float64
#  10  viruses      7996 non-null   float64
#  11  lead         7996 non-null   float64
#  12  nitrates     7996 non-null   float64
#  13  nitrites     7996 non-null   float64
#  14  mercury      7996 non-null   float64
#  15  perchlorate  7996 non-null   float64
#  16  radium       7996 non-null   float64
#  17  selenium     7996 non-null   float64
# ...

# %% [markdown]
# ### Data Visualization

# %%
# Let's first check the class distribution

data['is_safe'].value_counts()
# Out:
# is_safe
# Unsafe    7084
# Safe       912
# Name: count, dtype: int64

# %%
# Let's create a Pie-Chart to graphically represent the class distribution

import plotly.graph_objects as go

labels = ['Unsafe', 'Safe']

fig = go.Figure(data=[go.Pie(labels=labels, values=data['is_safe'].value_counts().values, pull=[0, 0.05])])
fig.show()

# %% [markdown]
# ***The majority of water samples in a dataset are unsafe, around 88.6% water samples in a dataset are unsafe whereas 11.4% water samples are safe.***

# %%
data.columns
# Out:
# Index(['aluminium', 'ammonia', 'arsenic', 'barium', 'cadmium', 'chloramine',
#        'chromium', 'copper', 'flouride', 'bacteria', 'viruses', 'lead',
#        'nitrates', 'nitrites', 'mercury', 'perchlorate', 'radium', 'selenium',
#        'silver', 'uranium', 'is_safe'],
#       dtype='object')

# %% [markdown]
# ## 1. Data Preparation

# %% [markdown]
# #### Handling Categorical Data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

data['is_safe'] = le.fit_transform(data['is_safe'])

# %%
data.head()
# Out:
#    aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65     9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32    21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01    14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36    11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92    24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# 3      1.08      0.71  ...  0.016      1.41      1.29    0.004         9.12
# 4      0.61      0.13  ...  0.117      6.74      1.11    0.003        16.90
#
# ...

# %%
## Data Splitting

X = data.drop('is_safe', axis = 1)
y = data['is_safe']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 20)

# %%
X_train.shape, X_test.shape
# Out:
# ((6396, 20), (1600, 20))

# %% [markdown]
# ## Model Building

# %% [markdown]
# #### 1. Support Vector Machine

# %%
# Support Vector Machine
from sklearn import svm
classifier = svm.SVC(kernel = 'rbf')

#fit the model
classifier.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Make a prediction for the testing set
y_pred_te = classifier.predict(X_test)

# %% [markdown]
# #### 2. Random Forest

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Making prediction on test data

pred_rf = rf.predict(X_test)

# %% [markdown]
# #### 3.Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression(max_iter=1000, random_state=42)
log_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
y_pred_log = log_model.predict(X_test)

# %% [markdown]
# #### 4.Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_dt = dt_model.predict(X_test)

# %% [markdown]
# #### 5.K-Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn_model.predict(X_test)
# Out:
#   File "c:\Users\shubh\.vscode\ML_Mini_Project\.venv312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 247, in _count_physical_cores
#     cpu_count_physical = _count_physical_cores_win32()
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\shubh\.vscode\ML_Mini_Project\.venv312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 299, in _count_physical_cores_win32
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python312\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python312\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Program Files\Python312\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# ...

# %% [markdown]
# #### 6. Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb = nb_model.predict(X_test)

# %% [markdown]
# #### 7. Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb_model = GradientBoostingClassifier(random_state=42)
gb_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_pred_gb = gb_model.predict(X_test)

# %% [markdown]
# #### 8.Extra Trees Classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

et_model = ExtraTreesClassifier(random_state=42)
et_model.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(random_state=42)

# %%
y_pred_et = et_model.predict(X_test)

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Since, it's a binary classification task and the dataset is imbalanced so we are going to use Precision, Recall, F1-score and ROC-AUC score to evaluate the performance of the model.

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, roc_auc_score

# %%
# Support Vector Machine (SVM) - Evaluation (Precision, Recall, F1, AUC)
print("🔹 Support Vector Machine (SVM) Evaluation Metrics 🔹")
print("Precision:", precision_score(y_test, y_pred_te))
print("Recall:", recall_score(y_test, y_pred_te))
print("F1-Score:", f1_score(y_test, y_pred_te))
print("ROC-AUC Score:", roc_auc_score(y_test, y_pred_te))
# Out:
# 🔹 Support Vector Machine (SVM) Evaluation Metrics 🔹
# Precision: 0.88625
# Recall: 1.0
# F1-Score: 0.9396951623591783
# ROC-AUC Score: 0.5

# %%
# Random Forest Classifier - Evaluation (Precision, Recall, F1, AUC)
print("🔹 Random Forest Classifier Evaluation Metrics 🔹")
print("Precision:", precision_score(y_test, pred_rf))
print("Recall:", recall_score(y_test, pred_rf))
print("F1-Score:", f1_score(y_test, pred_rf))
print("ROC-AUC Score:", roc_auc_score(y_test, pred_rf))
# Out:
# 🔹 Random Forest Classifier Evaluation Metrics 🔹
# Precision: 0.9578518014955812
# Recall: 0.9936530324400564
# F1-Score: 0.9754240221529941
# ROC-AUC Score: 0.8264968458903579

# %%
# Logistic Regression - Evaluation (Precision, Recall, F1, AUC)
print("Logistic Regression Performance Metrics:")
print("Precision:", precision_score(y_test, y_pred_log))
print("Recall:", recall_score(y_test, y_pred_log))
print("F1-score:", f1_score(y_test, y_pred_log))
print("ROC-AUC:", roc_auc_score(y_test, y_pred_log))
# Out:
# Logistic Regression Performance Metrics:
# Precision: 0.9143045484508899
# Recall: 0.9781382228490832
# F1-score: 0.945144804088586
# ROC-AUC: 0.6319262542816845

# %%
# Decision Tree Classifier - Evaluation (Precision, Recall, F1, AUC)
print("Decision Tree Performance Metrics:")
print("Precision:", precision_score(y_test, y_pred_dt))
print("Recall:", recall_score(y_test, y_pred_dt))
print("F1-score:", f1_score(y_test, y_pred_dt))
print("ROC-AUC:", roc_auc_score(y_test, y_pred_dt))
# Out:
# Decision Tree Performance Metrics:
# Precision: 0.9732958538299368
# Recall: 0.9767277856135402
# F1-score: 0.975008799718409
# ROC-AUC: 0.8839682884111657

# %%
# K-Nearest Neighbors - Evaluation (Precision, Recall, F1, AUC)
print("K-Nearest Neighbors Performance Metrics:")
print("Precision:", precision_score(y_test, y_pred_knn))
print("Recall:", recall_score(y_test, y_pred_knn))
print("F1-score:", f1_score(y_test, y_pred_knn))
print("ROC-AUC:", roc_auc_score(y_test, y_pred_knn))
# Out:
# K-Nearest Neighbors Performance Metrics:
# Precision: 0.8972691807542262
# Recall: 0.9732016925246827
# F1-score: 0.9336941813261164
# ROC-AUC: 0.5525349121964073

# %%
# Gaussian Naive Bayes - Evaluation (Precision, Recall, F1, AUC)
print("Gaussian Naive Bayes Performance Metrics:")
print("Precision:", precision_score(y_test, y_pred_nb))
print("Recall:", recall_score(y_test, y_pred_nb))
print("F1-score:", f1_score(y_test, y_pred_nb))
print("ROC-AUC:", roc_auc_score(y_test, y_pred_nb))
# Out:
# Gaussian Naive Bayes Performance Metrics:
# Precision: 0.946319018404908
# Recall: 0.8702397743300423
# F1-score: 0.9066862601028656
# ROC-AUC: 0.7428121948573289

# %%
# Gradient Boosting Classifier - Evaluation (Precision, Recall, F1, AUC)
print("Gradient Boosting Classifier Performance Metrics:")
print("Precision:", precision_score(y_test, y_pred_gb))
print("Recall:", recall_score(y_test, y_pred_gb))
print("F1-score:", f1_score(y_test, y_pred_gb))
print("ROC-AUC:", roc_auc_score(y_test, y_pred_gb))
# Out:
# Gradient Boosting Classifier Performance Metrics:
# Precision: 0.9630642954856361
# Recall: 0.9929478138222849
# F1-score: 0.9777777777777777
# ROC-AUC: 0.8481222585594941

# %%
# Extra Trees Classifier - Evaluation (Precision, Recall, F1, AUC)
print("Extra Trees Classifier Performance Metrics:")
print("Precision:", precision_score(y_test, y_pred_et))
print("Recall:", recall_score(y_test, y_pred_et))
print("F1-score:", f1_score(y_test, y_pred_et))
print("ROC-AUC:", roc_auc_score(y_test, y_pred_et))
# Out:
# Extra Trees Classifier Performance Metrics:
# Precision: 0.9357429718875502
# Recall: 0.9858956276445698
# F1-score: 0.9601648351648352
# ROC-AUC: 0.7292115500860212

# %%
#  Summary of All Model Accuracies
import pandas as pd

accuracy_summary = {
    "Random Forest": precision_score(y_test, pred_rf),
    "SVM": precision_score(y_test, y_pred_te),
    "Logistic Regression": precision_score(y_test, y_pred_log),
    "Decision Tree": precision_score(y_test, y_pred_dt),
    "KNN": precision_score(y_test, y_pred_knn),
    "Naive Bayes": precision_score(y_test, y_pred_nb),
    "Gradient Boosting": precision_score(y_test, y_pred_gb),
    "Extra Trees": precision_score(y_test, y_pred_et)
}

summary_df = pd.DataFrame(accuracy_summary.items(), columns=["Model", "precision_score"])
display(summary_df.sort_values(by="precision_score", ascending=False))
# Out:
#                  Model  precision_score
# 3        Decision Tree         0.973296
# 6    Gradient Boosting         0.963064
# 0        Random Forest         0.957852
# 5          Naive Bayes         0.946319
# 7          Extra Trees         0.935743
# 2  Logistic Regression         0.914305
# 4                  KNN         0.897269
# 1                  SVM         0.886250

# %% [markdown]
# ## 2. Model Hyper Parameter Tunning
#
# We are going to use Randomized Search CV to tune the hyperparameters of Random Forest classifier as it computationally faster as compared to another tunning methods. So, we should use such tunning method which is having good computational speed especially when we are dealing with the large data set.

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1000, num = 10)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt', 'log2']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(3, 50, 20)]

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 8,10, 12]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,6,8]


random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
              'criterion':['entropy', 'gini impurity']}

# %%
model_rscv = RandomizedSearchCV(
    estimator=rf,
    param_distributions=random_grid,
    n_iter=20,      
    cv=3,          
    n_jobs=-1,
    random_state=42,
    verbose=2
)
model_rscv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=20,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['entropy',
#                                                       'gini impurity'],
#                                         'max_depth': [3, 5, 7, 10, 12, 15, 17,
#                                                       20, 22, 25, 27, 30, 32,
#                                                       35, 37, 40, 42, 45, 47,
#                                                       50],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 6, 8],
#                                         'min_samples_split': [2, 5, 8, 10, 12],
#                                         'n_estimators': [100, 200, 300, 400,
# ...

# %%
model_rscv.best_params_
# Out:
# {'n_estimators': 600,
#  'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 22,
#  'criterion': 'entropy'}

# %%
best_random = model_rscv.best_estimator_
best_random
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=22, min_samples_split=5,
#                        n_estimators=600)

# %%
# Making Prediction

y_pred_rf_rscv = best_random.predict(X_test)

# %% [markdown]
# ## 3. Model Evaluation with AUC Score

# %% [markdown]
# We are going to use ROC AUC Score for the evaluation of the model as we should use it when we care equally about positive and negative classes especially in case of imbalanced data. So, since the dataset is imbalanced and we need to take care about true negatives as much as we care about true positives then it totally makes sense to use ROC AUC.

# %%
# Evaluation

from sklearn.metrics import confusion_matrix, classification_report
print("Precision Score: ", precision_score(y_test, y_pred_rf_rscv))
print("Recall Score: ", recall_score(y_test, y_pred_rf_rscv))
print("F1-Score: ", f1_score(y_test, y_pred_rf_rscv))
print("AUC Score: ", roc_auc_score(y_test, y_pred_rf_rscv))
print(classification_report(y_test, y_pred_rf_rscv))
# Out:
# Precision Score:  0.9585316111488783
# Recall Score:  0.9943582510578279
# F1-Score:  0.9761163032191069
# AUC Score:  0.8295967079464964
#               precision    recall  f1-score   support
#
#            0       0.94      0.66      0.78       182
#            1       0.96      0.99      0.98      1418
#
#     accuracy                           0.96      1600
#    macro avg       0.95      0.83      0.88      1600
# weighted avg       0.96      0.96      0.95      1600

# %% [markdown]
# ## 4. Feature Selection to avoid Overfitting
#
# Since the dataset contains so many columns so there might be a possibility that only few columns are impacting the target variable but we are using all the feature to build the model and probably leads to overfitting. So, to avoid overfitting we can simply drop those features which are least important to build the model.

# %%
# view the feature scores

feature_scores = pd.Series(rf.feature_importances_, index=X_train.columns, ).sort_values(ascending=False)
feature_scores
# Out:
# aluminium      0.214689
# cadmium        0.112133
# perchlorate    0.110779
# arsenic        0.061777
# silver         0.049567
# chloramine     0.047328
# ammonia        0.046902
# nitrates       0.039662
# chromium       0.034111
# uranium        0.033821
# radium         0.033787
# nitrites       0.030982
# bacteria       0.030163
# viruses        0.028907
# barium         0.027353
# lead           0.024835
# copper         0.024339
# flouride       0.019013
# selenium       0.016608
# mercury        0.013243
# dtype: float64

# %%
# Plot the bar graph to check of the features visually
feature_scores.plot(kind="bar",figsize=(16, 9))
# Out:
# <Axes: >

# %%
X_train
# Out:
#       aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 5108       0.08     0.33     0.09    0.75    0.030        0.07      0.06
# 3715       0.04    15.27     0.41    2.90    0.010        2.45      0.05
# 4141       0.06     3.62     0.01    0.18    0.090        0.02      0.05
# 5110       0.06    15.77     0.06    1.52    0.050        0.17      0.04
# 5226       0.07    16.98     0.08    0.41    0.090        0.60      0.09
# ...         ...      ...      ...     ...      ...         ...       ...
# 7068       0.08     4.16     0.09    0.91    0.100        0.19      0.09
# 7391       0.08    14.53     0.09    0.67    0.020        0.39      0.08
# 4367       0.01     5.12     0.06    2.22    0.090        0.08      0.08
# 2522       0.06    27.94     0.02    1.45    0.001        4.36      0.17
# 7523       0.05    12.74     0.01    0.19    0.000        0.39      0.02
#
#       copper  flouride  bacteria  viruses   lead  nitrates  nitrites  mercury  \
# ...

# %%
X_train.columns
# Out:
# Index(['aluminium', 'ammonia', 'arsenic', 'barium', 'cadmium', 'chloramine',
#        'chromium', 'copper', 'flouride', 'bacteria', 'viruses', 'lead',
#        'nitrates', 'nitrites', 'mercury', 'perchlorate', 'radium', 'selenium',
#        'silver', 'uranium'],
#       dtype='object')

# %%
# drop the least important feature from X_train and X_test

X_train = X_train.drop(labels = ['flouride', 'selenium', 'mercury'], axis =  1)
X_test = X_test.drop(labels = ['flouride', 'selenium', 'mercury'], axis = 1)

# %%
X_test
# Out:
#       aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 3671       0.14    28.73     0.89    0.33    0.110        0.11      0.31
# 97         2.85    23.02     0.03    2.24    0.004        0.46      0.02
# 5285       0.02    11.30     0.04    1.74    0.070        0.04      0.07
# 3830       0.20    20.25     0.48    2.52    0.050        5.28      0.74
# 2394       0.05    11.99     0.04    3.22    0.009        1.10      0.65
# ...         ...      ...      ...     ...      ...         ...       ...
# 3065       0.17    19.86     0.23    3.84    0.040        4.55      0.89
# 5818       0.04    28.48     0.09    3.87    0.080        0.17      0.02
# 6398       0.05    21.69     0.05    0.75    0.100        0.30      0.10
# 5098       0.06    10.20     0.06    0.17    0.090        0.32      0.08
# 3798       0.02     8.96     0.95    3.99    0.010        6.95      0.43
#
#       copper  bacteria  viruses   lead  nitrates  nitrites  perchlorate  \
# ...

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 100, criterion='entropy', max_depth=50,
                                             min_samples_split = 2, min_samples_leaf = 1, max_features= 'sqrt')
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=50)

# %%
# Making Prediction

y_pred_rf_sel = model.predict(X_test)

# %%
# Evaluation

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report, roc_auc_score, auc
print("Precision Score: ", precision_score(y_test, y_pred_rf_sel))
print("Recall Score: ", recall_score(y_test, y_pred_rf_sel))
print("F1-Score: ", f1_score(y_test, y_pred_rf_sel))
print("AUC Score: ", roc_auc_score(y_test, y_pred_rf_sel))
print(classification_report(y_test, y_pred_rf_sel))
# Out:
# Precision Score:  0.961038961038961
# Recall Score:  0.9915373765867419
# F1-Score:  0.9760499826449149
# AUC Score:  0.8391752816999644
#               precision    recall  f1-score   support
#
#            0       0.91      0.69      0.78       182
#            1       0.96      0.99      0.98      1418
#
#     accuracy                           0.96      1600
#    macro avg       0.94      0.84      0.88      1600
# weighted avg       0.96      0.96      0.95      1600

# %%
import pickle

filename = 'Water_Quality_Prediction_System.pkl'

# Open the file in binary write mode ('wb')
with open(filename, 'wb') as file:
  # Dump the trained model object ('model') into the file
  # Make sure 'model' is the variable holding your final trained RandomForest model
  pickle.dump(model, file)

print(f"Model saved successfully to {filename}")
# Out:
# Model saved successfully to Water_Quality_Prediction_System.pkl

# %% [markdown]
# ### Plot the ROC curve

# %%
from sklearn import metrics

plt.figure(figsize = (13, 7))
false_positive_rate, true_positive_rate, thresholds = metrics.roc_curve(y_test, y_pred_rf_sel)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.plot(false_positive_rate, true_positive_rate,label='AUC Level = %0.2f' % (roc_auc))
plt.legend(loc='lower right')
plt.plot([0, 1], [0, 1], 'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## 5. Result Analysis
#
# After evaluating multiple classification algorithms, it was observed that the **Random Forest Classifier** and **Support Vector Classifier (SVC)** consistently delivered the highest overall performance in terms of **Accuracy**, **Precision**, **Recall**, and **F1-score**.
#
# ---
#
# ### **Random Forest Classifier**
# The **Random Forest Classifier** demonstrated strong predictive power due to its *ensemble nature*, which reduces overfitting by averaging the results of multiple decision trees.
# It effectively captured the **nonlinear relationships** among key features such as **pH**, **Solids**, and **Sulfate**, making it highly suitable for this dataset.
#
# **Key Advantages:**
# - Reduces variance and overfitting through ensemble averaging
# - Handles nonlinearity and feature interactions well
# - Provides feature importance for better interpretability
#
# ---
#
# ###  **Support Vector Classifier (SVC)**
# The **Support Vector Classifier** performed comparably well, especially with the **RBF kernel**, which efficiently separated the two water potability classes — *potable* and *non-potable* — in a nonlinear feature space.
# Its ability to generalize from limited data contributed to its **stable and accurate predictions**.
#
# **Key Advantages:**
# - Works well in high-dimensional and nonlinear spaces
# - Robust to overfitting, especially with kernel-based transformations
# - Provides strong performance even with small datasets
#
# ---
#
# ###  **Other Models Overview**
#
# | Model | Performance Summary |
# |:------|:--------------------|
# | **Logistic Regression** | Performed decently but limited by linear decision boundaries |
# | **Decision Tree Classifier** | Easy to interpret but prone to overfitting |
# | **K-Nearest Neighbors (KNN)** | Sensitive to noisy data and feature scaling |
# | **Gaussian Naive Bayes** | Fast but limited due to independence assumption |
# | **Gradient Boosting Classifier** | Competitive but required heavy tuning |
# | **Extra Trees Classifier** | High accuracy but computationally expensive |
#
# ---
#
# ###  **Final Model Selection**
#
# Based on both **performance metrics** and **deployment efficiency**, the final model selection focuses on:
#
#  **Random Forest Classifier**
#  **Support Vector Classifier (SVC)**
#
# These models offer the **best trade-off** between:
# - High predictive accuracy
# - Model interpretability
# - Scalability and real-world usability
#
# Thus, they were chosen as the **final models** for **predicting water potability** with optimal precision and reliability.
